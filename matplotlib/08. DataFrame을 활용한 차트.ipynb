# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 3
#       1 import matplotlib.pyplot as plt
#       2 import koreanize_matplotlib
# ----> 3 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
data = {
    '이름' : ['채치수', '정대만', '송태섭', '서태웅', '강백호', '변덕규', '황태산', '윤대협'],
    '학교' : ['북산고', '북산고', '북산고', '북산고', '북산고', '능남고', '능남고', '능남고'],
    '키' : [197, 184, 168, 187, 188, 202, 188, 190],
    '국어' : [90, 40, 80, 40, 15, 80, 55, 100],
    '영어' : [85, 35, 75, 60, 20, 100, 65, 85],
    '수학' : [100, 50, 70, 70, 10, 95, 45, 90],
    '과학' : [95, 55, 80, 75, 35, 85, 40, 95],
    '사회' : [85, 25, 75, 80, 10, 80, 35, 95],
    'SW특기' : ['Python', 'Java', 'Javascript', '', '', 'C', 'PYTHON', 'C#']
}

# %%
# g = plt.plot(df['이름'],df['국어'])
g = plt.plot('이름','국어',data=df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 # g = plt.plot(df['이름'],df['국어'])
# ----> 2 g = plt.plot('이름','국어',data=df)
#
# NameError: name 'df' is not defined

# %%
plt.plot('이름','국어',data=df)
plt.plot('이름','영어',data=df)
plt.plot('이름','수학',data=df)
g = plt.plot(ncol=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 plt.plot('이름','국어',data=df)
#       2 plt.plot('이름','영어',data=df)
#       3 plt.plot('이름','수학',data=df)
#
# NameError: name 'df' is not defined

# %%
plt.plot('이름','과학',data=df)
plt.plot('이름','영어',data=df)
plt.plot('이름','수학',data=df)
plt.grid(axis='y',alpha=0.3)
g = plt.plot(ncol=3)

# %%
df.to_csv("./data/students.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df.to_csv("./data/students.csv", index=False)
#
# NameError: name 'df' is not defined
